# %%
import pandas as pd

students = ({
    'std' : [1000, 1001, 1002, 1003],
    'name' : ['Ahmed', 'Emam', 'Abo Ne3ma', 'Tharwat'],
    'grade' : [47, 49, 48, 45]
})
df = pd.DataFrame(students)
df

student_name = ["Khaled", "Mahmoud", "Ali","Yousef"]
marks = [48, 49, 42, 46]
x = pd.Series(data = marks, index = student_name)
x
x["Ali"]
# Out:
# np.int64(42)
